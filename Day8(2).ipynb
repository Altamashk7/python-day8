# %%
import pandas as pd

# %%
df=pd.read_csv(r'C:\Users\Administrator\Downloads\pandas_questions.csv')

# %%
df.head(5)
# Out:
#     Na#me       Salar$y
# 0    Amit  $100,000.00
# 1   Sumit  $200,000.00
# 2   Suman  $600,000.00
# 3  Kir$an  $640,000.00
# 4    John  $569,999.00

# %%
#1
df.columns=df.columns.str.replace('[#, $, !, @, $, %, ^, &, * ,/, >,< ,?, ]', '', regex=True)
df
# Out:
#      Name        Salary
# 0    Amit  $100,000.00
# 1   Sumit  $200,000.00
# 2   Suman  $600,000.00
# 3  Kir$an  $640,000.00
# 4    John  $569,999.00
# 5  Lokesh           NaN
# 6     NaN  $300,000.00
# 7    Amar           NaN
# 8     NaN  $600,000.00

# %%
#2
df.Name=df.Name.str.replace('[#, $, !, @, $, %, ^, &, * ,/, >,< ,?,]', '', regex=True)
df
# Out:
#      Name        Salary
# 0    Amit  $100,000.00
# 1   Sumit  $200,000.00
# 2   Suman  $600,000.00
# 3   Kiran  $640,000.00
# 4    John  $569,999.00
# 5  Lokesh           NaN
# 6     NaN  $300,000.00
# 7    Amar           NaN
# 8     NaN  $600,000.00

# %%
#3
df.Salary=df.Salary.str.replace('[#, $, !, @, $, %, ^, &, * ,/, >,< ,?,]', '', regex=True)
df
# Out:
#      Name     Salary
# 0    Amit  100000.00
# 1   Sumit  200000.00
# 2   Suman  600000.00
# 3   Kiran  640000.00
# 4    John  569999.00
# 5  Lokesh        NaN
# 6     NaN  300000.00
# 7    Amar        NaN
# 8     NaN  600000.00

# %%
#4
df=df.dropna()

# %%
df
# Out:
#     Name     Salary
# 0   Amit  100000.00
# 1  Sumit  200000.00
# 2  Suman  600000.00
# 3  Kiran  640000.00
# 4   John  569999.00

# %%
#5
df["Net Salary"] = df.Salary.astype(float)*(0.7)
df
# Out:
# C:\Users\ADMINI~1\AppData\Local\Temp/ipykernel_4032/478731924.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Net Salary"] = df.Salary.astype(float)*(0.7)
#     Name     Salary  Net Salary
# 0   Amit  100000.00     70000.0
# 1  Sumit  200000.00    140000.0
# 2  Suman  600000.00    420000.0
# 3  Kiran  640000.00    448000.0
# 4   John  569999.00    398999.3

# %%
#6
df[df.Name.str[0]=='S'].Salary
df
# Out:
#     Name     Salary  Net Salary
# 0   Amit  100000.00     70000.0
# 1  Sumit  200000.00    140000.0
# 2  Suman  600000.00    420000.0
# 3  Kiran  640000.00    448000.0
# 4   John  569999.00    398999.3

# %%
#7
df["Int_Salary"]=df.Salary.astype(float).astype(int)
df
# Out:
# C:\Users\ADMINI~1\AppData\Local\Temp/ipykernel_4032/1389433201.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Int_Salary"]=df.Salary.astype(float).astype(int)
#     Name     Salary  Net Salary  Int_Salary
# 0   Amit  100000.00     70000.0      100000
# 1  Sumit  200000.00    140000.0      200000
# 2  Suman  600000.00    420000.0      600000
# 3  Kiran  640000.00    448000.0      640000
# 4   John  569999.00    398999.3      569999

# %%
#8
df[df.Salary==df.Salary.max()].Name
# Out:
# 3    Kiran
# Name: Name, dtype: object

# %%
#9
df[df.Name.str[-1]=='n'].Name
# Out:
# 2    Suman
# 3    Kiran
# 4     John
# Name: Name, dtype: object

# %%
#10
df.sort_values(by=['Name'])
# Out:
#     Name     Salary  Net Salary  Int_Salary
# 0   Amit  100000.00     70000.0      100000
# 4   John  569999.00    398999.3      569999
# 3  Kiran  640000.00    448000.0      640000
# 2  Suman  600000.00    420000.0      600000
# 1  Sumit  200000.00    140000.0      200000

# %%
#11
df[(df['Int_Salary']>400000)&(df['Int_Salary']<600000)]
# Out:
#    Name     Salary  Net Salary  Int_Salary
# 4  John  569999.00    398999.3      569999

# %%
#12
df.Salary.astype(float).mean()
# Out:
# 421999.8

# %%
df.plot.bar(x='Name', y="Int_Salary")
# Out:
# <AxesSubplot:xlabel='Name'>

# %%
#Question3

new_df=pd.read_csv(r'C:\Users\Administrator\Downloads\disbetes.csv')
new_df
# Out:
#       6  148  72  35    #  33.6  0.627  50  1
# 0     1   85  66  29    0  26.6  0.351  31  0
# 1     8  183  64   0    0  23.3  0.672  32  1
# 2     1   89  66  23   94  28.1  0.167  21  0
# 3     0  137  40  35  168  43.1  2.288  33  1
# 4     5  116  74   0    0  25.6  0.201  30  0
# ..   ..  ...  ..  ..  ...   ...    ...  .. ..
# 762  10  101  76  48  180  32.9  0.171  63  0
# 763   2  122  70  27    0  36.8  0.340  27  0
# 764   5  121  72  23  112  26.2  0.245  30  0
# 765   1  126  60   0    0  30.1  0.349  47  1
# 766   1   93  70  31    0  30.4  0.315  23  0
#
# [767 rows x 9 columns]

# %%
new_text=pd.read_csv(r'C:\Users\Administrator\Downloads\diabetes_column_heading.txt', sep="\t", header=None, error_bad_lines=False)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
new_text
# Out:
#                                                    0
# 0                        0. Number of times pregnant
# 1                    1. Plasma glucose concentration
# 2                2. Diastolic blood pressure (mm Hg)
# 3                 3. Triceps skinfold thickness (mm)
# 4                  4. 2-Hour serum insulin (mu U/ml)
# 5  5. Body mass index (weight in kg/(height in m)^2)
# 6                      6. Diabetes pedigree function
# 7                                     7. Age (years)
# 8                         8. Class variable (0 or 1)

# %%
new_text[0]
# Out:
# 0                          0. Number of times pregnant
# 1                      1. Plasma glucose concentration
# 2                  2. Diastolic blood pressure (mm Hg)
# 3                   3. Triceps skinfold thickness (mm)
# 4                    4. 2-Hour serum insulin (mu U/ml)
# 5    5. Body mass index (weight in kg/(height in m)^2)
# 6                        6. Diabetes pedigree function
# 7                                       7. Age (years)
# 8                           8. Class variable (0 or 1)
# Name: 0, dtype: object

# %%
new_text[0]=new_text[0].str.replace('[0-9,.]', '',regex=True)
new_text
# Out:
#                                                 0
# 0                        Number of times pregnant
# 1                    Plasma glucose concentration
# 2                Diastolic blood pressure (mm Hg)
# 3                 Triceps skinfold thickness (mm)
# 4                   -Hour serum insulin (mu U/ml)
# 5   Body mass index (weight in kg/(height in m)^)
# 6                      Diabetes pedigree function
# 7                                     Age (years)
# 8                           Class variable ( or )

# %%
new_text=new_text[0].str.replace(r"\(.*\)", "", regex=True)
new_text
# Out:
# 0         Number of times pregnant
# 1     Plasma glucose concentration
# 2        Diastolic blood pressure
# 3      Triceps skinfold thickness
# 4             -Hour serum insulin
# 5                 Body mass index
# 6       Diabetes pedigree function
# 7                             Age
# 8                  Class variable
# Name: 0, dtype: object

# %%
new_df.columns=new_text
new_df
# Out:
# 0     Number of times pregnant   Plasma glucose concentration  \
# 0                            1                             85
# 1                            8                            183
# 2                            1                             89
# 3                            0                            137
# 4                            5                            116
# ..                         ...                            ...
# 762                         10                            101
# 763                          2                            122
# 764                          5                            121
# 765                          1                            126
# 766                          1                             93
#
# 0    Diastolic blood pressure    Triceps skinfold thickness   \
# 0                           66                            29
# 1                           64                             0
# ...

# %%
#1
print(new_df.isnull().sum())
# Out:
# 0
#  Number of times pregnant        0
#  Plasma glucose concentration    0
#  Diastolic blood pressure        1
#  Triceps skinfold thickness      0
#  -Hour serum insulin             0
#  Body mass index                 0
#  Diabetes pedigree function      0
#  Age                             1
#  Class variable                  0
# dtype: int64

# %%
new_df
# Out:
# 0     Number of times pregnant   Plasma glucose concentration  \
# 0                            1                             85
# 1                            8                            183
# 2                            1                             89
# 3                            0                            137
# 4                            5                            116
# ..                         ...                            ...
# 762                         10                            101
# 763                          2                            122
# 764                          5                            121
# 765                          1                            126
# 766                          1                             93
#
# 0    Diastolic blood pressure    Triceps skinfold thickness   \
# 0                           66                            29
# 1                           64                             0
# ...

# %%
new_df.columns
# Out:
# Index([' Number of times pregnant', ' Plasma glucose concentration',
#        ' Diastolic blood pressure ', ' Triceps skinfold thickness ',
#        ' -Hour serum insulin ', ' Body mass index ',
#        ' Diabetes pedigree function', ' Age ', ' Class variable '],
#       dtype='object', name=0)

# %%
#2
new_df.astype(bool).sum(axis=0)
# Out:
# 0
#  Number of times pregnant        656
#  Plasma glucose concentration    762
#  Diastolic blood pressure        767
#  Triceps skinfold thickness      540
#  -Hour serum insulin             767
#  Body mass index                 756
#  Diabetes pedigree function      767
#  Age                             767
#  Class variable                  267
# dtype: int64

# %%
(new_df== 0).sum(axis=0)
# Out:
# 0
#  Number of times pregnant        111
#  Plasma glucose concentration      5
#  Diastolic blood pressure          0
#  Triceps skinfold thickness      227
#  -Hour serum insulin               0
#  Body mass index                  11
#  Diabetes pedigree function        0
#  Age                               0
#  Class variable                  500
# dtype: int64

# %%
import numpy as np
new_df = new_df.replace(0, np.NaN)
new_df
# Out:
# 0     Number of times pregnant   Plasma glucose concentration  \
# 0                          1.0                           85.0
# 1                          8.0                          183.0
# 2                          1.0                           89.0
# 3                          NaN                          137.0
# 4                          5.0                          116.0
# ..                         ...                            ...
# 762                       10.0                          101.0
# 763                        2.0                          122.0
# 764                        5.0                          121.0
# 765                        1.0                          126.0
# 766                        1.0                           93.0
#
# 0    Diastolic blood pressure    Triceps skinfold thickness   \
# 0                           66                          29.0
# 1                           64                           NaN
# ...

# %%
(new_df).isna().sum()
# Out:
# 0
#  Number of times pregnant        111
#  Plasma glucose concentration      5
#  Diastolic blood pressure          1
#  Triceps skinfold thickness      227
#  -Hour serum insulin               0
#  Body mass index                  11
#  Diabetes pedigree function        0
#  Age                               1
#  Class variable                  500
# dtype: int64

# %%
#3
new_df1=new_df.copy(deep=True)
new_df1
# Out:
# 0     Number of times pregnant   Plasma glucose concentration  \
# 0                          1.0                           85.0
# 1                          8.0                          183.0
# 2                          1.0                           89.0
# 3                          NaN                          137.0
# 4                          5.0                          116.0
# ..                         ...                            ...
# 762                       10.0                          101.0
# 763                        2.0                          122.0
# 764                        5.0                          121.0
# 765                        1.0                          126.0
# 766                        1.0                           93.0
#
# 0    Diastolic blood pressure    Triceps skinfold thickness   \
# 0                           66                          29.0
# 1                           64                           NaN
# ...

# %%
new_df.dropna(how='all')
# Out:
# 0     Number of times pregnant   Plasma glucose concentration  \
# 0                          1.0                           85.0
# 1                          8.0                          183.0
# 2                          1.0                           89.0
# 3                          NaN                          137.0
# 4                          5.0                          116.0
# ..                         ...                            ...
# 762                       10.0                          101.0
# 763                        2.0                          122.0
# 764                        5.0                          121.0
# 765                        1.0                          126.0
# 766                        1.0                           93.0
#
# 0    Diastolic blood pressure    Triceps skinfold thickness   \
# 0                           66                          29.0
# 1                           64                           NaN
# ...

# %%
new_df1.shape[0]
# Out:
# 767

# %%
new_df1.dropna()
# Out:
# 0     Number of times pregnant   Plasma glucose concentration  \
# 5                          3.0                           78.0
# 7                          2.0                          197.0
# 12                         1.0                          189.0
# 18                         1.0                          115.0
# 22                         9.0                          119.0
# ..                         ...                            ...
# 745                        1.0                          147.0
# 747                        3.0                          187.0
# 753                        8.0                          154.0
# 754                        1.0                          128.0
# 760                        9.0                          170.0
#
# 0    Diastolic blood pressure    Triceps skinfold thickness   \
# 5                           50                          32.0
# 7                           70                          45.0
# ...

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
new_df.corr()
# Out:
# 0                               Number of times pregnant  \
# 0
#  Number of times pregnant                       1.000000
#  Plasma glucose concentration                   0.165836
#  Triceps skinfold thickness                     0.166663
#  Body mass index                                0.128055
#  Diabetes pedigree function                    -0.006833
#  Class variable                                      NaN
#
# 0                               Plasma glucose concentration  \
# 0
#  Number of times pregnant                           0.165836
#  Plasma glucose concentration                       1.000000
#  Triceps skinfold thickness                         0.227359
#  Body mass index                                    0.232700
#  Diabetes pedigree function                         0.136805
#  Class variable                                          NaN
#
# 0                               Triceps skinfold thickness   \
# 0
# ...

# %%
sns.heatmap(new_df.corr());

# %%
new_df.var()
# Out:
# C:\Users\ADMINI~1\AppData\Local\Temp/ipykernel_4032/3957107709.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   new_df.var()
# 0
#  Number of times pregnant         10.363301
#  Plasma glucose concentration    932.739607
#  Triceps skinfold thickness      109.907273
#  Body mass index                  48.017249
#  Diabetes pedigree function        0.109890
#  Class variable                    0.000000
# dtype: float64

# %%
ratio_missing = new_df.isnull().sum()/len(new_df)

# %%
ratio_missing
# Out:
# 0
#  Number of times pregnant        0.144720
#  Plasma glucose concentration    0.006519
#  Diastolic blood pressure        0.001304
#  Triceps skinfold thickness      0.295958
#  -Hour serum insulin             0.000000
#  Body mass index                 0.014342
#  Diabetes pedigree function      0.000000
#  Age                             0.001304
#  Class variable                  0.651890
# dtype: float64
